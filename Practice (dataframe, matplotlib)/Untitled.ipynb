# %%
import pandas as pd
import qgrid

# %%
df = pd.read_csv('result.csv')
df
# Out:
#         Unnamed: 0  order_id                     product  qt   price   total  \
# 0                0    176558        USB-C Charging Cable   2   11.95   23.90
# 1                1    176559  Bose SoundSport Headphones   1   99.99   99.99
# 2                2    176560                Google Phone   1  600.00  600.00
# 3                3    176560            Wired Headphones   1   11.99   11.99
# 4                4    176561            Wired Headphones   1   11.99   11.99
# ...            ...       ...                         ...  ..     ...     ...
# 185945      185945    259353      AAA Batteries (4-pack)   3    2.99    8.97
# 185946      185946    259354                      iPhone   1  700.00  700.00
# 185947      185947    259355                      iPhone   1  700.00  700.00
# 185948      185948    259356      34in Ultrawide Monitor   1  379.99  379.99
# 185949      185949    259357        USB-C Charging Cable   1   11.95   11.95
#
# ...

# %%
qgrid.show_grid(df)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
