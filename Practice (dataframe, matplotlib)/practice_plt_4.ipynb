# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv', sep=',')
df.head()
# Out:
#    order_id                     product  qt   price   total  \
# 0    176558        USB-C Charging Cable   2   11.95   23.90
# 1    176559  Bose SoundSport Headphones   1   99.99   99.99
# 2    176560                Google Phone   1  600.00  600.00
# 3    176560            Wired Headphones   1   11.99   11.99
# 4    176561            Wired Headphones   1   11.99   11.99
#
#             order_date                               address
# 0  2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 1  2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 2  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4  2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   order_id    185950 non-null  int64
#  1   product     185950 non-null  object
#  2   qt          185950 non-null  int64
#  3   price       185950 non-null  float64
#  4   total       185950 non-null  float64
#  5   order_date  185950 non-null  object
#  6   address     185950 non-null  object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 48.9 MB

# %%
# df['order_date'] = pd.to_datetime(df.order_date, format=r'%Y-%m-%d %H:%M:%S')
df.order_date = df.order_date.apply(lambda x: pd.to_datetime(arg=x, format=r'%Y-%m-%d %H:%M:%S'))

# %%
df.head()
# Out:
#    order_id                     product  qt   price   total  \
# 0    176558        USB-C Charging Cable   2   11.95   23.90
# 1    176559  Bose SoundSport Headphones   1   99.99   99.99
# 2    176560                Google Phone   1  600.00  600.00
# 3    176560            Wired Headphones   1   11.99   11.99
# 4    176561            Wired Headphones   1   11.99   11.99
#
#            order_date                               address
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   order_id    185950 non-null  int64
#  1   product     185950 non-null  object
#  2   qt          185950 non-null  int64
#  3   price       185950 non-null  float64
#  4   total       185950 non-null  float64
#  5   order_date  185950 non-null  datetime64[ns]
#  6   address     185950 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 36.8 MB

# %%
df['month'] = df['order_date'].dt.month

# %%
df
# Out:
#         order_id                     product  qt   price   total  \
# 0         176558        USB-C Charging Cable   2   11.95   23.90
# 1         176559  Bose SoundSport Headphones   1   99.99   99.99
# 2         176560                Google Phone   1  600.00  600.00
# 3         176560            Wired Headphones   1   11.99   11.99
# 4         176561            Wired Headphones   1   11.99   11.99
# ...          ...                         ...  ..     ...     ...
# 185945    259353      AAA Batteries (4-pack)   3    2.99    8.97
# 185946    259354                      iPhone   1  700.00  700.00
# 185947    259355                      iPhone   1  700.00  700.00
# 185948    259356      34in Ultrawide Monitor   1  379.99  379.99
# 185949    259357        USB-C Charging Cable   1   11.95   11.95
#
#                 order_date                                  address  month
# 0      2019-04-19 08:46:00             917 1st St, Dallas, TX 75001      4
# ...

# %%
df.to_csv('result.csv', sep=',', index=False)
