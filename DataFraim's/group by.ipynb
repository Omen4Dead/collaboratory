# %%
import pandas as pd

# %%
city_df = pd.read_csv('city.csv', sep=';')
city_df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
city_df[ city_df.CountryCode == 'AFG' ]['Population'].sum()
# Out:
# 2332100

# %%
city_df.groupby('CountryCode').sum()['Population']
# Out:
# CountryCode
# ABW       29034
# AFG     2332100
# AGO     2561600
# AIA        1556
# ALB      270000
#          ...
# YEM     1743700
# YUG     2189507
# ZAF    15196370
# ZMB     2473500
# ZWE     2730420
# Name: Population, Length: 232, dtype: int64

# %%
city_df.groupby('CountryCode').agg(['min', 'max', 'sum', 'mean', 'count'])['Population']
# Out:
# C:\Users\111\AppData\Local\Temp\ipykernel_16748\815750870.py:1: FutureWarning: ['Name', 'District'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   city_df.groupby('CountryCode').agg(['min', 'max', 'sum', 'mean', 'count'])['Population']
#                 min      max       sum           mean  count
# CountryCode
# ABW           29034    29034     29034   29034.000000      1
# AFG          127800  1780000   2332100  583025.000000      4
# AGO          118200  2022000   2561600  512320.000000      5
# AIA             595      961      1556     778.000000      2
# ALB          270000   270000    270000  270000.000000      1
# ...             ...      ...       ...            ...    ...
# YEM          103300   503600   1743700  290616.666667      6
# YUG           92303  1204000   2189507  273688.375000      8
# ZAF           89292  2352121  15196370  345372.045455     44
# ...

# %%
code_group = city_df.groupby('CountryCode')
code_group

# %%
for index, value in code_group:
    print(index)
    print(value)
# Out:
# ABW
#       ID        Name CountryCode District  Population
# 128  129  Oranjestad         ABW        –       29034
# AFG
#    ID            Name CountryCode  District  Population
# 0   1           Kabul         AFG     Kabol     1780000
# 1   2        Qandahar         AFG  Qandahar      237500
# 2   3           Herat         AFG     Herat      186800
# 3   4  Mazar-e-Sharif         AFG     Balkh      127800
# AGO
#     ID      Name CountryCode  District  Population
# 55  56    Luanda         AGO    Luanda     2022000
# 56  57    Huambo         AGO    Huambo      163100
# 57  58    Lobito         AGO  Benguela      130000
# 58  59  Benguela         AGO  Benguela      128300
# 59  60    Namibe         AGO    Namibe      118200
# AIA
#     ID        Name CountryCode District  Population
# 60  61  South Hill         AIA        –         961
# 61  62  The Valley         AIA        –         595
# ALB
#     ID    Name CountryCode District  Population
# ...

# %%
code_group.get_group('AFG')
# Out:
#    ID            Name CountryCode  District  Population
# 0   1           Kabul         AFG     Kabol     1780000
# 1   2        Qandahar         AFG  Qandahar      237500
# 2   3           Herat         AFG     Herat      186800
# 3   4  Mazar-e-Sharif         AFG     Balkh      127800

# %%
code_group.describe()['Population']
# Out:
#              count           mean            std       min        25%  \
# CountryCode
# ABW            1.0   29034.000000            NaN   29034.0   29034.00
# AFG            4.0  583025.000000  799241.458614  127800.0  172050.00
# AGO            5.0  512320.000000  844105.862437  118200.0  128300.00
# AIA            2.0     778.000000     258.801082     595.0     686.50
# ALB            1.0  270000.000000            NaN  270000.0  270000.00
# ...            ...            ...            ...       ...        ...
# YEM            6.0  290616.666667  155648.468244  103300.0  166425.00
# YUG            8.0  273688.375000  377226.883552   92303.0  126346.50
# ZAF           44.0  345372.045455  366793.373731   89292.0  166479.00
# ZMB            7.0  353357.142857  433110.412625  118100.0  133150.00
# ZWE            6.0  455070.000000  503661.219871  128037.0  139615.75
#
#                   50%        75%        max
# CountryCode
# ABW           29034.0   29034.00    29034.0
# ...

# %% [markdown]
# # HW

# %%
df = pd.read_csv('city.csv', sep=';')
df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
df_group = df.groupby(['CountryCode'])
df_group

# %%
stat_df = df_group.agg(['max', 'min'])['Population'].head(10)
stat_df
# Out:
# C:\Users\111\AppData\Local\Temp\ipykernel_16748\585359767.py:1: FutureWarning: ['District'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   stat_df = df_group.agg(['max', 'min'])['Population'].head(10)
#                  max     min
# CountryCode
# ABW            29034   29034
# AFG          1780000  127800
# AGO          2022000  118200
# AIA              961     595
# ALB           270000  270000
# AND            21189   21189
# ANT             2345    2345
# ARE           669181  114395
# ARG          2982146   91101
# ARM          1248700  172700

# %%
stat_df.reset_index()
# Out:
#   CountryCode      max     min
# 0         ABW    29034   29034
# 1         AFG  1780000  127800
# 2         AGO  2022000  118200
# 3         AIA      961     595
# 4         ALB   270000  270000
# 5         AND    21189   21189
# 6         ANT     2345    2345
# 7         ARE   669181  114395
# 8         ARG  2982146   91101
# 9         ARM  1248700  172700

# %%
df2 = pd.read_csv('city.csv', sep=';')
df2
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
df_group2 = df.groupby(['CountryCode']).agg(['max', 'min'])['Population']
df_group2
# Out:
# C:\Users\111\AppData\Local\Temp\ipykernel_16748\641493866.py:1: FutureWarning: ['District'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_group2 = df.groupby(['CountryCode']).agg(['max', 'min'])['Population']
#                  max     min
# CountryCode
# ABW            29034   29034
# AFG          1780000  127800
# AGO          2022000  118200
# AIA              961     595
# ALB           270000  270000
# ...              ...     ...
# YEM           503600  103300
# YUG          1204000   92303
# ZAF          2352121   89292
# ZMB          1317000  118100
# ZWE          1410000  128037
#
# [232 rows x 2 columns]

# %%
df_group2['difference'] = df_group2['max'] - df_group2['min']
df_group2
# Out:
#                  max     min  difference
# CountryCode
# ABW            29034   29034           0
# AFG          1780000  127800     1652200
# AGO          2022000  118200     1903800
# AIA              961     595         366
# ALB           270000  270000           0
# ...              ...     ...         ...
# YEM           503600  103300      400300
# YUG          1204000   92303     1111697
# ZAF          2352121   89292     2262829
# ZMB          1317000  118100     1198900
# ZWE          1410000  128037     1281963
#
# [232 rows x 3 columns]

# %%
df_group2.head(10)
# Out:
#                  max     min  difference
# CountryCode
# ABW            29034   29034           0
# AFG          1780000  127800     1652200
# AGO          2022000  118200     1903800
# AIA              961     595         366
# ALB           270000  270000           0
# AND            21189   21189           0
# ANT             2345    2345           0
# ARE           669181  114395      554786
# ARG          2982146   91101     2891045
# ARM          1248700  172700     1076000
