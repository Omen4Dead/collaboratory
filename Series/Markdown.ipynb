# %% [markdown]
# #Заголовок 1
# ## Заголовок 2
# ### Заголовок 3
# #### Заголовок 4
# Язык разметки `Markdown`

# %% [markdown]
# * El1
# * El2
#     * El2.1
# * El3

# %% [markdown]
# ```python
# print('Hello')
# ```
# ---
# ```python
# with open() as e:
#     pass
# ```
